# %%
import numpy as np
import pandas as pd

# %%
pd.read_csv('results/xgboost_pred_speed.csv')
pd.read_csv('results/xgboost_accuracy.csv')
# Out:
#     base_binary_accu  base_binary_auc  base_scenario_accu  past_n_steps  \
# 0              0.811            0.511               0.665            48
# 1              0.811            0.511               0.665            48
# 2              0.811            0.511               0.665            48
# 3              0.813            0.512               0.666            48
# 4              0.813            0.513               0.668            48
# 5              0.815            0.512               0.667            48
# 6              0.814            0.512               0.667            48
# 7              0.812            0.509               0.663            48
# 8              0.811            0.509               0.661            48
# 9              0.808            0.510               0.659            48
# 10             0.805            0.511               0.655            48
# 11             0.802            0.514               0.652            48
# ...
