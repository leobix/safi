# %%
import pandas as pd
import numpy as np
from pandas import read_csv
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot

from pandas import DataFrame
from pandas import concat
from sklearn.metrics import mean_squared_error

from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error

from statsmodels.tsa.arima_model import ARIMA

from datetime import date, datetime, timedelta

# %% [markdown]
# # Data Preparation

# %%
from data_preperation import * 
avg_data=prepare_data(one_hot=False)
data_merge = prepare_data_with_forecast(avg_data)
# Out:
# read csv semester csv files from 2015s2 to 2019s2
# smooth wind direction
# smooth hour
# smooth day
# generate daily features: ['daily_min_speed', 'daily_min_hour', 'daily_max_speed', 'daily_max_hour']
# generate seasonality categorical feature
# generate day/night categorical feature
# merged with forecast data ['f00', 'f12', 'f24', 'f36', 'f48']

# %% [markdown]
# # Data Exploration

# %%
avg_data.tail(5)
# Out:
#                      hour  speed    temp  radiation  precip  scenario_num  \
# 2019-10-31 19:00:00  19.0  5.800  23.625        0.0     0.0           1.0
# 2019-10-31 20:00:00  20.0  5.350  23.500        0.0     0.0           1.0
# 2019-10-31 21:00:00  21.0  5.125  23.050        0.0     0.0           1.0
# 2019-10-31 22:00:00  22.0  5.025  22.675        0.0     0.0           1.0
# 2019-10-31 23:00:00  23.0  5.575  22.425        0.0     0.0           1.0
#
#                      cos_wind_dir  sin_wind_dir  cos_hour  sin_hour   cos_day  \
# 2019-10-31 19:00:00      0.717855      0.693237  0.351308 -0.933402  0.495697
# 2019-10-31 20:00:00      0.511087      0.859053  0.580919 -0.810672  0.495697
# 2019-10-31 21:00:00      0.495896      0.867648  0.770942 -0.632696  0.495697
# 2019-10-31 22:00:00      0.528096      0.844972  0.908427 -0.411603  0.495697
# 2019-10-31 23:00:00      0.554406      0.829741  0.984004 -0.162460  0.495697
#
#                       sin_day  daily_min_speed  daily_min_hour  \
# 2019-10-31 19:00:00  0.868496            3.075             4.0
# 2019-10-31 20:00:00  0.868496            3.075             4.0
# 2019-10-31 21:00:00  0.868496            3.075             4.0
# 2019-10-31 22:00:00  0.868496            3.075             4.0
# 2019-10-31 23:00:00  0.868496            3.075             4.0
#
#                      daily_max_speed  daily_max_hour  season  day  night
# 2019-10-31 19:00:00              5.8            19.0       4    0      1
# 2019-10-31 20:00:00              5.8            19.0       4    0      1
# 2019-10-31 21:00:00              5.8            19.0       4    0      1
# 2019-10-31 22:00:00              5.8            19.0       4    0      1
# 2019-10-31 23:00:00              5.8            19.0       4    0      1

# %% [markdown]
# # Data exploration

# %%
df1= generate_daily_min(avg_data)
print("total number of days =", df1.shape[0])

plt.figure()
plt.hist(df1['min_hour'].values)
plt.ylabel('occurance count')
plt.xlabel('hour of the day')
plt.title('hour distribution of daily min speed')
# plt.savefig('daily_min_speed_hour_distr.png')
plt.show()

plt.figure()
plt.hist(df1['max_hour'].values)
plt.ylabel('occurance count')
plt.xlabel('hour of the day')
plt.title('hour distribution of daily max speed')
# plt.savefig('daily_max_speed_hour_distr.png')
plt.show()
# Out:
# total number of days = 1584

# %%
#5-day-average daily min 
plt.plot(df1.head(365).resample('5D').mean()['min_speed'], label='min speed')
plt.plot(df1.head(365).resample('5D').mean()['max_speed'], label='max speed')
plt.ylabel('5-day-avg daily min wind speed')
plt.xlabel('date')
plt.title('5-day-avg daily min & max wind speed over 1 year')
plt.legend()
# plt.savefig('daily_min_max_speed_5d_avg.png')
# Out:
# /Users/cynthiazeng/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# plt.figure(figsize=(20,10))
plt.rcParams["figure.figsize"] = (8,5)
plt.show()
bad = avg_data.loc[avg_data['scenario_num']>=3]['hour']
bad_days= bad.resample('M').count()
plt.plot(bad_days)
plt.ylabel('number of alerts')
plt.xlabel('date')
plt.title('Number of >=3 Scenarios Alerts per Month')
# plt.savefig('scenario 3&4 alerts per month.png')
# Out:
# Text(0.5, 1.0, 'Number of >=3 Scenarios Alerts per Month')

# %%
#count distribution of scenarios
avg_data['scenario_num'].value_counts(normalize=True)
# avg_data['speed'].value_counts(normalize=True)
# Out:
# 1.0    0.717461
# 2.0    0.243608
# 3.0    0.035380
# 4.0    0.003551
# Name: scenario_num, dtype: float64

# %%
plt.plot(avg_data.resample('D').sum()['precip'])
# plt.plot(avg_data.head(365).resample('5D').mean()['radiation'], label='max speed')
plt.ylabel('daily-avg precipitation level')
plt.xlabel('date')
plt.title('Daily sum of precipitation level')
# plt.savefig('Daily precipitation level.png')
# plt.legend()
# Out:
# Text(0.5, 1.0, 'Daily sum of precipitation level')

# %%
# avg_data.loc['2018-01-01':].resample('D').mean()['precip']
s= pd.to_numeric(avg_data['precip'])
s.loc['2018-01-01':].resample('D').mean()
# Out:
# 2018-01-01    0.008333
# 2018-01-02    0.008333
# 2018-01-03    0.158333
# 2018-01-04    0.008333
# 2018-01-05    0.016667
# 2018-01-06    1.383333
# 2018-01-07    0.883333
# 2018-01-08    1.658333
# 2018-01-09    6.291667
# 2018-01-10    2.973958
# 2018-01-11    0.016667
# 2018-01-12    0.025000
# 2018-01-13    0.008333
# 2018-01-14    0.000000
# 2018-01-15    1.191667
# 2018-01-16    0.091667
# 2018-01-17    0.191667
# 2018-01-18    1.475000
# 2018-01-19    1.225000
# 2018-01-20    1.233333
# 2018-01-21    1.091667
# 2018-01-22    0.516667
# 2018-01-23    2.325000
# 2018-01-24    0.683333
# 2018-01-25    0.025000
# 2018-01-26    0.050000
# 2018-01-27    0.516667
# 2018-01-28    0.008333
# 2018-01-29    0.025000
# 2018-01-30    0.008333
#                 ...
# 2019-10-02    0.000000
# 2019-10-03    0.000000
# 2019-10-04    0.000000
# 2019-10-05    0.000000
# 2019-10-06    0.000000
# 2019-10-07    0.000000
# 2019-10-08    0.000000
# 2019-10-09    0.000000
# 2019-10-10    0.000000
# 2019-10-11    0.000000
# 2019-10-12    0.000000
# 2019-10-13    0.000000
# 2019-10-14    0.033333
# 2019-10-15    0.000000
# 2019-10-16    0.000000
# 2019-10-17    0.000000
# 2019-10-18    0.000000
# 2019-10-19    0.000000
# 2019-10-20    0.025000
# 2019-10-21    0.000000
# 2019-10-22    0.158333
# 2019-10-23    0.008333
# 2019-10-24    0.000000
# 2019-10-25    0.000000
# 2019-10-26    0.000000
# 2019-10-27    0.000000
# 2019-10-28    0.091667
# 2019-10-29    0.008333
# 2019-10-30    0.000000
# 2019-10-31    0.000000
# Freq: D, Name: precip, Length: 669, dtype: float64

# %%
plt.plot(avg_data.resample('7D').mean()['radiation'])
plt.ylabel('daily-avg radiation level')
plt.xlabel('date')
plt.title('5-day-avg radiation level')
# plt.savefig('5-day-avg radiation level.png')
# plt.legend()
# Out:
# Text(0.5, 1.0, '5-day-avg radiation level')

# %% [markdown]
# # Get classification datasets

# %%
data = avg_data
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequences)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the dataset
		if out_end_ix > len(sequences):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

n = 28000

# define input sequence
in_seq1 = np.array(data["speed"])[:n]
in_seq2 = np.array(data["cos_wind_dir"])[:n]
in_seq3 = np.array(data["sin_wind_dir"])[:n]
in_seq4 = np.array(data["temp"])[:n]
in_seq5 = np.array(data["radiation"])[:n]
in_seq6 = np.array(data["precip"])[:n]
in_seq7 = np.array(data["cos_hour"])[:n]
in_seq8 = np.array(data["sin_hour"])[:n]
in_seq9 = np.array(data["cos_day"])[:n]
in_seq10 = np.array(data["sin_day"])[:n]
in_seq11 = np.array(data["scenario_num"])[:n]

# convert to [rows, columns] structure
in_seq1 = in_seq1.reshape((len(in_seq1), 1))
in_seq2 = in_seq2.reshape((len(in_seq2), 1))
in_seq3 = in_seq3.reshape((len(in_seq3), 1))
in_seq4 = in_seq4.reshape((len(in_seq4), 1))
in_seq5 = in_seq5.reshape((len(in_seq5), 1))
in_seq6 = in_seq6.reshape((len(in_seq6), 1))
in_seq7 = in_seq7.reshape((len(in_seq7), 1))
in_seq8 = in_seq8.reshape((len(in_seq8), 1))
in_seq9 = in_seq9.reshape((len(in_seq9), 1))
in_seq10 = in_seq10.reshape((len(in_seq10), 1))
in_seq11 = in_seq11.reshape((len(in_seq11), 1))


# horizontally stack columns
dataset = np.hstack((in_seq1, in_seq2, in_seq3, in_seq4, in_seq5, in_seq6, in_seq7, in_seq8, in_seq9, in_seq10, in_seq11))
# choose a number of time steps
n_steps_in, n_steps_out = 24, 48
# convert into input/output
X, y = split_sequences(dataset, n_steps_in, n_steps_out)
#if you want y to be classification: set scenario to be max of all scenarios in the hours 24-48
X = X[:,:,:3]
y = np.amax(y[:,23:29,10], axis = 1)

# %%
y_train_one_class = y.copy()
for i in range(len(y)):
    if y[i] > 1:
        y_train_one_class[i] = 1
    else:
        y_train_one_class[i] = 0

# %%
# For XGBoost, Trees etc, data needs to be 2D, so we need to flatten the vector
X_train = X.reshape(len(X), n_steps_in*3)

# %%
#m is the number of examples to test
m = 10000

# define input sequence
in_seq1 = np.array(data["speed"])[n:n+m]
in_seq2 = np.array(data["cos_wind_dir"])[n:n+m]
in_seq3 = np.array(data["sin_wind_dir"])[n:n+m]
in_seq4 = np.array(data["temp"])[n:n+m]
in_seq5 = np.array(data["radiation"])[n:n+m]
in_seq6 = np.array(data["precip"])[n:n+m]
in_seq7 = np.array(data["cos_hour"])[n:n+m]
in_seq8 = np.array(data["sin_hour"])[n:n+m]
in_seq9 = np.array(data["cos_day"])[n:n+m]
in_seq10 = np.array(data["sin_day"])[n:n+m]
in_seq11 = np.array(data["scenario_num"])[n:n+m]

# convert to [rows, columns] structure
in_seq1 = in_seq1.reshape((len(in_seq1), 1))
in_seq2 = in_seq2.reshape((len(in_seq2), 1))
in_seq3 = in_seq3.reshape((len(in_seq3), 1))
in_seq4 = in_seq4.reshape((len(in_seq4), 1))
in_seq5 = in_seq5.reshape((len(in_seq5), 1))
in_seq6 = in_seq6.reshape((len(in_seq6), 1))
in_seq7 = in_seq7.reshape((len(in_seq7), 1))
in_seq8 = in_seq8.reshape((len(in_seq8), 1))
in_seq9 = in_seq9.reshape((len(in_seq9), 1))
in_seq10 = in_seq10.reshape((len(in_seq10), 1))
in_seq11 = in_seq11.reshape((len(in_seq11), 1))


# horizontally stack columns
dataset_test = np.hstack((in_seq1, in_seq2, in_seq3, in_seq4, in_seq5, in_seq6, in_seq7, in_seq8, in_seq9, in_seq10, in_seq11))
# convert into input/output
X_test, y_test = split_sequences(dataset_test, n_steps_in, n_steps_out)
#if you want y to be classification: set scenario to be max of all scenarios in the hours 24-48
X_test = X_test[:,:,:3]
y_test = np.amax(y_test[:,23:29,10], axis = 1)
# For XGBoost, Trees etc, data needs to be 2D, so we need to flatten the vector
X_test = X_test.reshape(len(X_test), n_steps_in*3)

# %%
y_test_one_class = y_test.copy()
for i in range(len(y_test)):
    if y_test[i] > 1:
        y_test_one_class[i] = 1
    else:
        y_test_one_class[i] = 0

# %% [markdown]
# # Distribution of scenarios

# %%
plt.hist(data.scenario_num)
plt.show()

# %%
plt.hist(avg_data.scenario_num)
plt.show()

# %%
# windspeed repartition
plt.hist(avg_data.speed, bins = 50)
plt.show()

# %% [markdown]
# # Some visualizations, plots, analysis of the data

# %% [markdown]
# ## Simple plot to show cyclicity of the features

# %%
df = avg_data
n=200 
plt.rcParams["figure.figsize"] = (20,10)


plt.plot(df['speed'].head(n))
plt.show()

# %%
n = 1000
df = data
plt.plot(df["speed"].head(n))
plt.plot(df["cos_wind_dir"].head(n))
plt.plot(df["sin_wind_dir"].head(n))
plt.rcParams["figure.figsize"] = (20,10)
plt.show()

# %% [markdown]
# ## $y_{t+n}$ wrt $y_t$

# %%
plt.rcParams["figure.figsize"] = (10,10)
y = df["speed"]
lag_plot(y)
pyplot.show()

# %%
y = data[["speed"]]
for i in range(1, 50, 10):
    lag_plot(y, lag = i)
    plt.rcParams["figure.figsize"] = (10,10)
    pyplot.show()

# %% [markdown]
# # Seasonal analysis of the data

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
df_speed = data["speed"][:10000]
df_speed.index = pd.DatetimeIndex(freq="w", start=0, periods=len(df_speed))
decomposed = seasonal_decompose(df_speed, model='additive')
x = decomposed.plot() #See note below about this
plt.show()
# Out:
# /Users/leobix/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## Autocorrelation plot

# %%
autocorrelation_plot(y.head(100))
plt.rcParams["figure.figsize"] = (5,5)
pyplot.show()

# %%
autocorrelation_plot(data["speed"].head(4000).tail(100))
plt.rcParams["figure.figsize"] = (10,10)
pyplot.show()

# %% [markdown]
# # Rolling mean

# %%
rolling_mean = y.rolling(window = 12).mean()
rolling_std = y.rolling(window = 12).std()
plt.plot(y, color = 'blue', label = 'Original')
plt.plot(rolling_mean, color = 'red', label = 'Rolling Mean')
plt.plot(rolling_std, color = 'black', label = 'Rolling Std')
plt.legend(loc = 'best')
plt.title('Rolling Mean & Rolling Standard Deviation')
plt.show()

# %% [markdown]
# # Very simple prototyped prediction models

# %%
series = data.speed
# create lagged dataset
values = DataFrame(series.values)
dataframe = concat([values.shift(1), values], axis=1)
dataframe.columns = ['t-1', 't+1']
# split into train and test sets
X = dataframe.values
train, test = X[1:len(X)-7], X[len(X)-7:]
train_X, train_y = train[:,0], train[:,1]
test_X, test_y = test[:,0], test[:,1]

# persistence model
def model_persistence(x):
	return x

# walk-forward validation
predictions = list()
for x in test_X:
	yhat = model_persistence(x)
	predictions.append(yhat)
test_score = mean_squared_error(test_y, predictions)
print('Test MSE: %.3f' % test_score)
# plot predictions vs expected
pyplot.plot(test_y)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# Test MSE: 0.120

# %%
series = data.speed
# split dataset
X = series.values
train, test = X[1:len(X)-7], X[len(X)-7:]
# train autoregression
model = AR(train)
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
for i in range(len(predictions)):
	print('predicted=%f, expected=%f' % (predictions[i], test[i]))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot results
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# Lag: 75
# Coefficients: [ 1.15845741e-01  8.54939077e-01  3.69066097e-02  3.19144434e-02
#   1.57148965e-02  9.89786331e-03 -1.39713268e-04 -6.96727857e-03
#  -7.38020355e-05  5.05316664e-03 -4.22690847e-03  1.00270264e-03
#   3.38341768e-03 -8.17083661e-03 -3.30534677e-03  2.97181306e-03
#   4.34260451e-03  2.86021860e-03  2.36364714e-03  4.46456649e-03
#   1.56618941e-03 -9.09528208e-03  1.24522514e-03  4.91888314e-03
#  -8.51147254e-03  2.25938127e-03  2.94842194e-03 -3.38077627e-03
#   2.24185567e-03 -2.30787131e-03  2.81760294e-03  3.89001141e-03
#   1.74730452e-04 -1.01089706e-02  5.26548459e-03  6.39499803e-03
#  -6.53552997e-04 -5.80161823e-03 -3.94120887e-03 -4.42787165e-03
#   4.66537561e-03  2.56353562e-03  1.23005530e-03 -4.20588949e-03
#   5.24369413e-04 -5.23976868e-03  1.72378916e-03  2.80734016e-03
#  -7.91001668e-03  2.48177047e-03  1.29945023e-03 -2.09869085e-03
#  -1.35334491e-04  1.49735088e-03  2.69496569e-03  4.34537197e-04
#  -2.81132949e-03 -1.88736112e-03  1.07638343e-03  3.29973423e-03
#   1.28457563e-03 -3.34466088e-03 -5.71182772e-04  8.34877278e-04
#   5.48062006e-03 -5.33283896e-03  3.06968028e-03 -1.18631185e-03
#   1.42624316e-02 -1.10568350e-02 -6.13046941e-03  1.74251680e-03
#   3.88302485e-03  5.40813545e-03  2.66136005e-03  1.77594146e-02]
# predicted=4.847544, expected=4.600000
# predicted=4.771153, expected=5.100000
# predicted=4.684445, expected=5.500000
# predicted=4.615656, expected=5.200000
# predicted=4.539819, expected=5.700000
# predicted=4.504239, expected=5.700000
# predicted=4.451289, expected=5.700000
# Test MSE: 0.787

# %%
series = data["speed"]
# split dataset
X = series.values
train, test = X[1:len(X)-24], X[len(X)-24:]
# train autoregression
model = AR(train)
model_fit = model.fit()
window = model_fit.k_ar
coef = model_fit.params
# walk forward over time steps in test
history = train[len(train)-window:]
history = [history[i] for i in range(len(history))]
predictions = list()
for t in range(len(test)):
	length = len(history)
	lag = [history[i] for i in range(length-window,length)]
	yhat = coef[0]
	for d in range(window):
		yhat += coef[d+1] * lag[window-d-1]
	obs = test[t]
	predictions.append(yhat)
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=5.444221, expected=6.200000
# predicted=5.969262, expected=5.200000
# predicted=5.196177, expected=5.200000
# predicted=5.219058, expected=4.700000
# predicted=4.727747, expected=5.400000
# predicted=5.281308, expected=6.100000
# predicted=5.891172, expected=6.300000
# predicted=6.114362, expected=5.400000
# predicted=5.351573, expected=5.300000
# predicted=5.233812, expected=5.500000
# predicted=5.411869, expected=5.200000
# predicted=5.121331, expected=5.400000
# predicted=5.259510, expected=5.300000
# predicted=5.183133, expected=5.100000
# predicted=5.028278, expected=5.300000
# predicted=5.207626, expected=4.800000
# predicted=4.783596, expected=4.900000
# predicted=4.847548, expected=4.600000
# predicted=4.559363, expected=5.100000
# predicted=4.956511, expected=5.500000
# predicted=5.317199, expected=5.200000
# predicted=5.076144, expected=5.700000
# predicted=5.546454, expected=5.700000
# predicted=5.551073, expected=5.700000
# Test MSE: 0.199

# %%
model = ARIMA(data["speed"], order=(2,1,2))
results = model.fit(disp=-1)

# %%
plt.plot(results.fittedvalues, color='red')
plt.show()

# %% [markdown]
# # LSTM
#
# I started to write some code for an LSTM prediction, but it needs to be adapted to our format.

# %%
# multivariate multi-step encoder-decoder lstm example
from numpy import array
from numpy import hstack
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
import numpy as np

from keras.callbacks import ModelCheckpoint
# Out:
# /Users/leobix/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /Users/leobix/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:455: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/leobix/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:456: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/leobix/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:457: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/leobix/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:458: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/leobix/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:459: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/leobix/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:462: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
	X, y = list(), list()
	for i in range(len(sequences)):
		# find the end of this pattern
		end_ix = i + n_steps_in
		out_end_ix = end_ix + n_steps_out
		# check if we are beyond the dataset
		if out_end_ix > len(sequences):
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequences[i:end_ix, :], sequences[end_ix:out_end_ix, :]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

n = 25000

# define input sequence
in_seq1 = np.array(data["speed"])[:n]
in_seq2 = np.array(data["cos_wind_dir"])[:n]
in_seq3 = np.array(data["sin_wind_dir"])[:n]

# convert to [rows, columns] structure
in_seq1 = in_seq1.reshape((len(in_seq1), 1))
in_seq2 = in_seq2.reshape((len(in_seq2), 1))
in_seq3 = in_seq3.reshape((len(in_seq3), 1))

# horizontally stack columns
dataset = np.hstack((in_seq1, in_seq2, in_seq3))
# choose a number of time steps
n_steps_in, n_steps_out = 48, 48
# convert into input/output
X, y = split_sequences(dataset, n_steps_in, n_steps_out)

# %%
# the dataset knows the number of features
n_features = X.shape[2]
# define model
model = Sequential()

model.add(LSTM(64, activation='relu', input_shape=(n_steps_in, n_features)))
model.add(RepeatVector(n_steps_out))
model.add(LSTM(64, activation='relu', return_sequences=True))
model.add(TimeDistributed(Dense(n_features)))#, activation='softmax')))
model.compile(optimizer='adam', loss='mse')
# fit model
checkpoints = ModelCheckpoint('Users.safi', monitor='val_acc', verbose=1,
                                save_best_only=False, save_weights_only=True,
                                mode='auto', period=1)

model.fit(X, y, epochs=10, verbose=0, callbacks = [checkpoints])#, validation_data=(X_test, y_test),)
# Out:
# Epoch 00001: saving model to Users.safi
# Epoch 00002: saving model to Users.safi
# Epoch 00003: saving model to Users.safi
# Epoch 00004: saving model to Users.safi
# Epoch 00005: saving model to Users.safi
# Epoch 00006: saving model to Users.safi
# Epoch 00007: saving model to Users.safi
# Epoch 00008: saving model to Users.safi
# Epoch 00009: saving model to Users.safi
# Epoch 00010: saving model to Users.safi

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 64)                17408
# _________________________________________________________________
# repeat_vector_2 (RepeatVecto (None, 192, 64)           0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 192, 64)           33024
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 192, 3)            195
# =================================================================
# Total params: 50,627
# Trainable params: 50,627
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Now we test the model

# %%
#m is the number of examples to test
m = 30000

# define input sequence
test_seq1 = np.array(data["speed"])[n:(n+m)]
test_seq2 = np.array(data["cos_wind_dir"])[n:(n+m)]
test_seq3 = np.array(data["sin_wind_dir"])[n:(n+m)]

# convert to [rows, columns] structure
test_seq1 = test_seq1.reshape((len(test_seq1), 1))
test_seq2 = test_seq2.reshape((len(test_seq2), 1))
test_seq3 = test_seq3.reshape((len(test_seq3), 1))

# horizontally stack columns
dataset_test = np.hstack((test_seq1, test_seq2, test_seq3))
# choose a number of time steps
# convert into input/output
X_test, y_test = split_sequences(dataset_test, n_steps_in, n_steps_out)

# %%
X_test.shape
# Out:
# (29329, 480, 3)

# %%
#our prediction
yhat_test = model.predict(X_test[0].reshape(1, 480, 3))
yhat_attempt = []
for i in range(len(X_test)):
    s = X_test[i,-1,0]
    c = X_test[i,-1,1]
    sin = X_test[i,-1,2]
    yhat_attempt.append([[s, c, sin] for i in range(n_steps_out)])
yhat_attempt = np.array(yhat_attempt)

# %%
yhat_test
# Out:
# array([[[nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan],
#         [nan, nan, nan]]], dtype=float32)

# %%
# one example of prediction
n = 10
pred = np.round(yhat_test[n,:,0], 1)
test = y_test[n,:,0]
print("prediction", pred)
print("real data", test)
plt.plot([15*i for i in range(n_steps_out)], pred)
plt.plot([15*i for i in range(n_steps_out)], test)
plt.show()
# Out:
# prediction [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan]
# real data [3.7        3.8        3.8        3.2        4.         3.
#  2.4        2.2        2.4        2.3        2.7        3.2
#  3.3        3.4        3.2        4.         3.7        3.7
#  3.3        2.7        4.4        3.8        3.7        2.2
#  1.5        1.1        1.9        2.8        3.6        3.5
#  3.7        3.7        3.6        3.6        3.6        3.7
#  3.7        3.5        4.         3.1        2.8        3.4
#  2.9        3.1        3.1        2.1        1.2        1.4
#  3.1        4.4        3.6        4.5        4.6        5.2
#  6.2        5.8        6.9        6.9        7.6        8.2
#  8.2        8.6        8.2        6.5        5.8        5.9
#  5.7        5.9        6.1        5.3        4.1        4.1
#  4.7        5.1        5.1        4.8        3.7        3.5
#  3.8        3.2        3.3        4.         3.9        3.
#  2.6        3.         3.3        2.9        2.5        3.
#  3.9        3.6        2.8        3.3        2.7        2.9
#  2.7        2.         1.4        2.3        2.7        2.
#  2.1        2.07142857 2.04285714 2.01428571 1.98571429 1.95714286
#  1.92857143 1.9        1.8        2.4        2.3        2.1
#  2.7        2.8        2.8        3.         3.3        3.6
#  3.7        3.1        3.2        3.9        4.3        3.9
#  4.6        3.8        3.1        3.9        3.9        3.6
#  4.4        4.6        4.9        4.5        4.5        4.6
#  4.9        4.2        4.2        4.5        4.2        4.
#  3.8        4.2        3.1        3.8        2.7        3.8
#  4.8        5.16       5.52       5.88       6.24       6.6
#  6.8        7.7        7.7        7.9        7.3        6.6
#  6.5        5.8        5.4        5.4        5.4        5.4
#  4.9        4.9        4.9        4.9        4.1        4.1
#  5.1        5.1        4.1        4.1        2.2        1.5
#  1.6        3.         3.         3.         2.1        2.1
#  2.1        2.1        1.6        1.6        1.6        1.6       ]

# %%
def loss(yhat, ytest, pred = 0):
    n = yhat.shape[0]
    err = []
    err_mean = []
    err_mean_abs = []
    for i in range(n):
        err.append(np.sum((np.round(yhat[i,:,pred], 1)-ytest[i,:,pred])**2))
        err_mean.append(list((np.round(yhat[i,:,pred], 1)-ytest[i,:,pred])**2))
        err_mean_abs.append(list(abs(np.round(yhat[i,:,pred], 1)-ytest[i,:,pred])))
    return np.mean(err), np.array(err_mean), np.array(err_mean_abs)

err, err_mean, err_mean_abs = loss(yhat_test, y_test)
print("The MSE is:", err)
for i in range(n_steps_out):
    print("The mean squared error for the timestep", i+1, "is: ", np.mean(err_mean[:,i]))
print()
for i in range(n_steps_out):
    print("The mean absolute error for the timestep", i+1, "is: ", np.mean(err_mean_abs[:,i]))
# Out:
# The MSE is: nan
# The mean squared error for the timestep 1 is:  nan
# The mean squared error for the timestep 2 is:  nan
# The mean squared error for the timestep 3 is:  nan
# The mean squared error for the timestep 4 is:  nan
# The mean squared error for the timestep 5 is:  nan
# The mean squared error for the timestep 6 is:  nan
# The mean squared error for the timestep 7 is:  nan
# The mean squared error for the timestep 8 is:  nan
# The mean squared error for the timestep 9 is:  nan
# The mean squared error for the timestep 10 is:  nan
# The mean squared error for the timestep 11 is:  nan
# The mean squared error for the timestep 12 is:  nan
# The mean squared error for the timestep 13 is:  nan
# The mean squared error for the timestep 14 is:  nan
# The mean squared error for the timestep 15 is:  nan
# The mean squared error for the timestep 16 is:  nan
# The mean squared error for the timestep 17 is:  nan
# The mean squared error for the timestep 18 is:  nan
# The mean squared error for the timestep 19 is:  nan
# The mean squared error for the timestep 20 is:  nan
# The mean squared error for the timestep 21 is:  nan
# The mean squared error for the timestep 22 is:  nan
# The mean squared error for the timestep 23 is:  nan
# The mean squared error for the timestep 24 is:  nan
# The mean squared error for the timestep 25 is:  nan
# The mean squared error for the timestep 26 is:  nan
# The mean squared error for the timestep 27 is:  nan
# The mean squared error for the timestep 28 is:  nan
# The mean squared error for the timestep 29 is:  nan
# The mean squared error for the timestep 30 is:  nan
# The mean squared error for the timestep 31 is:  nan
# The mean squared error for the timestep 32 is:  nan
# The mean squared error for the timestep 33 is:  nan
# The mean squared error for the timestep 34 is:  nan
# The mean squared error for the timestep 35 is:  nan
# The mean squared error for the timestep 36 is:  nan
# The mean squared error for the timestep 37 is:  nan
# The mean squared error for the timestep 38 is:  nan
# The mean squared error for the timestep 39 is:  nan
# The mean squared error for the timestep 40 is:  nan
# The mean squared error for the timestep 41 is:  nan
# The mean squared error for the timestep 42 is:  nan
# The mean squared error for the timestep 43 is:  nan
# The mean squared error for the timestep 44 is:  nan
# The mean squared error for the timestep 45 is:  nan
# The mean squared error for the timestep 46 is:  nan
# The mean squared error for the timestep 47 is:  nan
# The mean squared error for the timestep 48 is:  nan
# The mean squared error for the timestep 49 is:  nan
# The mean squared error for the timestep 50 is:  nan
# The mean squared error for the timestep 51 is:  nan
# The mean squared error for the timestep 52 is:  nan
# The mean squared error for the timestep 53 is:  nan
# The mean squared error for the timestep 54 is:  nan
# The mean squared error for the timestep 55 is:  nan
# The mean squared error for the timestep 56 is:  nan
# The mean squared error for the timestep 57 is:  nan
# The mean squared error for the timestep 58 is:  nan
# The mean squared error for the timestep 59 is:  nan
# The mean squared error for the timestep 60 is:  nan
# The mean squared error for the timestep 61 is:  nan
# The mean squared error for the timestep 62 is:  nan
# The mean squared error for the timestep 63 is:  nan
# The mean squared error for the timestep 64 is:  nan
# The mean squared error for the timestep 65 is:  nan
# The mean squared error for the timestep 66 is:  nan
# The mean squared error for the timestep 67 is:  nan
# The mean squared error for the timestep 68 is:  nan
# The mean squared error for the timestep 69 is:  nan
# The mean squared error for the timestep 70 is:  nan
# The mean squared error for the timestep 71 is:  nan
# The mean squared error for the timestep 72 is:  nan
# The mean squared error for the timestep 73 is:  nan
# The mean squared error for the timestep 74 is:  nan
# The mean squared error for the timestep 75 is:  nan
# The mean squared error for the timestep 76 is:  nan
# The mean squared error for the timestep 77 is:  nan
# The mean squared error for the timestep 78 is:  nan
# The mean squared error for the timestep 79 is:  nan
# The mean squared error for the timestep 80 is:  nan
# The mean squared error for the timestep 81 is:  nan
# The mean squared error for the timestep 82 is:  nan
# The mean squared error for the timestep 83 is:  nan
# The mean squared error for the timestep 84 is:  nan
# The mean squared error for the timestep 85 is:  nan
# The mean squared error for the timestep 86 is:  nan
# The mean squared error for the timestep 87 is:  nan
# The mean squared error for the timestep 88 is:  nan
# The mean squared error for the timestep 89 is:  nan
# The mean squared error for the timestep 90 is:  nan
# The mean squared error for the timestep 91 is:  nan
# The mean squared error for the timestep 92 is:  nan
# The mean squared error for the timestep 93 is:  nan
# The mean squared error for the timestep 94 is:  nan
# The mean squared error for the timestep 95 is:  nan
# The mean squared error for the timestep 96 is:  nan
# The mean squared error for the timestep 97 is:  nan
# The mean squared error for the timestep 98 is:  nan
# The mean squared error for the timestep 99 is:  nan
# The mean squared error for the timestep 100 is:  nan
# The mean squared error for the timestep 101 is:  nan
# The mean squared error for the timestep 102 is:  nan
# The mean squared error for the timestep 103 is:  nan
# The mean squared error for the timestep 104 is:  nan
# The mean squared error for the timestep 105 is:  nan
# The mean squared error for the timestep 106 is:  nan
# The mean squared error for the timestep 107 is:  nan
# The mean squared error for the timestep 108 is:  nan
# The mean squared error for the timestep 109 is:  nan
# The mean squared error for the timestep 110 is:  nan
# The mean squared error for the timestep 111 is:  nan
# The mean squared error for the timestep 112 is:  nan
# The mean squared error for the timestep 113 is:  nan
# The mean squared error for the timestep 114 is:  nan
# The mean squared error for the timestep 115 is:  nan
# The mean squared error for the timestep 116 is:  nan
# The mean squared error for the timestep 117 is:  nan
# The mean squared error for the timestep 118 is:  nan
# The mean squared error for the timestep 119 is:  nan
# The mean squared error for the timestep 120 is:  nan
# The mean squared error for the timestep 121 is:  nan
# The mean squared error for the timestep 122 is:  nan
# The mean squared error for the timestep 123 is:  nan
# The mean squared error for the timestep 124 is:  nan
# The mean squared error for the timestep 125 is:  nan
# The mean squared error for the timestep 126 is:  nan
# The mean squared error for the timestep 127 is:  nan
# The mean squared error for the timestep 128 is:  nan
# The mean squared error for the timestep 129 is:  nan
# The mean squared error for the timestep 130 is:  nan
# The mean squared error for the timestep 131 is:  nan
# The mean squared error for the timestep 132 is:  nan
# The mean squared error for the timestep 133 is:  nan
# The mean squared error for the timestep 134 is:  nan
# The mean squared error for the timestep 135 is:  nan
# The mean squared error for the timestep 136 is:  nan
# The mean squared error for the timestep 137 is:  nan
# The mean squared error for the timestep 138 is:  nan
# The mean squared error for the timestep 139 is:  nan
# The mean squared error for the timestep 140 is:  nan
# The mean squared error for the timestep 141 is:  nan
# The mean squared error for the timestep 142 is:  nan
# The mean squared error for the timestep 143 is:  nan
# The mean squared error for the timestep 144 is:  nan
# The mean squared error for the timestep 145 is:  nan
# The mean squared error for the timestep 146 is:  nan
# The mean squared error for the timestep 147 is:  nan
# The mean squared error for the timestep 148 is:  nan
# The mean squared error for the timestep 149 is:  nan
# The mean squared error for the timestep 150 is:  nan
# The mean squared error for the timestep 151 is:  nan
# The mean squared error for the timestep 152 is:  nan
# The mean squared error for the timestep 153 is:  nan
# The mean squared error for the timestep 154 is:  nan
# The mean squared error for the timestep 155 is:  nan
# The mean squared error for the timestep 156 is:  nan
# The mean squared error for the timestep 157 is:  nan
# The mean squared error for the timestep 158 is:  nan
# The mean squared error for the timestep 159 is:  nan
# The mean squared error for the timestep 160 is:  nan
# The mean squared error for the timestep 161 is:  nan
# The mean squared error for the timestep 162 is:  nan
# The mean squared error for the timestep 163 is:  nan
# The mean squared error for the timestep 164 is:  nan
# The mean squared error for the timestep 165 is:  nan
# The mean squared error for the timestep 166 is:  nan
# The mean squared error for the timestep 167 is:  nan
# The mean squared error for the timestep 168 is:  nan
# The mean squared error for the timestep 169 is:  nan
# The mean squared error for the timestep 170 is:  nan
# The mean squared error for the timestep 171 is:  nan
# The mean squared error for the timestep 172 is:  nan
# The mean squared error for the timestep 173 is:  nan
# The mean squared error for the timestep 174 is:  nan
# The mean squared error for the timestep 175 is:  nan
# The mean squared error for the timestep 176 is:  nan
# The mean squared error for the timestep 177 is:  nan
# The mean squared error for the timestep 178 is:  nan
# The mean squared error for the timestep 179 is:  nan
# The mean squared error for the timestep 180 is:  nan
# The mean squared error for the timestep 181 is:  nan
# The mean squared error for the timestep 182 is:  nan
# The mean squared error for the timestep 183 is:  nan
# The mean squared error for the timestep 184 is:  nan
# The mean squared error for the timestep 185 is:  nan
# The mean squared error for the timestep 186 is:  nan
# The mean squared error for the timestep 187 is:  nan
# The mean squared error for the timestep 188 is:  nan
# The mean squared error for the timestep 189 is:  nan
# The mean squared error for the timestep 190 is:  nan
# The mean squared error for the timestep 191 is:  nan
# The mean squared error for the timestep 192 is:  nan
#
# The mean absolute error for the timestep 1 is:  nan
# The mean absolute error for the timestep 2 is:  nan
# The mean absolute error for the timestep 3 is:  nan
# The mean absolute error for the timestep 4 is:  nan
# The mean absolute error for the timestep 5 is:  nan
# The mean absolute error for the timestep 6 is:  nan
# The mean absolute error for the timestep 7 is:  nan
# The mean absolute error for the timestep 8 is:  nan
# The mean absolute error for the timestep 9 is:  nan
# The mean absolute error for the timestep 10 is:  nan
# The mean absolute error for the timestep 11 is:  nan
# The mean absolute error for the timestep 12 is:  nan
# The mean absolute error for the timestep 13 is:  nan
# The mean absolute error for the timestep 14 is:  nan
# The mean absolute error for the timestep 15 is:  nan
# The mean absolute error for the timestep 16 is:  nan
# The mean absolute error for the timestep 17 is:  nan
# The mean absolute error for the timestep 18 is:  nan
# The mean absolute error for the timestep 19 is:  nan
# The mean absolute error for the timestep 20 is:  nan
# The mean absolute error for the timestep 21 is:  nan
# The mean absolute error for the timestep 22 is:  nan
# The mean absolute error for the timestep 23 is:  nan
# The mean absolute error for the timestep 24 is:  nan
# The mean absolute error for the timestep 25 is:  nan
# The mean absolute error for the timestep 26 is:  nan
# The mean absolute error for the timestep 27 is:  nan
# The mean absolute error for the timestep 28 is:  nan
# The mean absolute error for the timestep 29 is:  nan
# The mean absolute error for the timestep 30 is:  nan
# The mean absolute error for the timestep 31 is:  nan
# The mean absolute error for the timestep 32 is:  nan
# The mean absolute error for the timestep 33 is:  nan
# The mean absolute error for the timestep 34 is:  nan
# The mean absolute error for the timestep 35 is:  nan
# The mean absolute error for the timestep 36 is:  nan
# The mean absolute error for the timestep 37 is:  nan
# The mean absolute error for the timestep 38 is:  nan
# The mean absolute error for the timestep 39 is:  nan
# The mean absolute error for the timestep 40 is:  nan
# The mean absolute error for the timestep 41 is:  nan
# The mean absolute error for the timestep 42 is:  nan
# The mean absolute error for the timestep 43 is:  nan
# The mean absolute error for the timestep 44 is:  nan
# The mean absolute error for the timestep 45 is:  nan
# The mean absolute error for the timestep 46 is:  nan
# The mean absolute error for the timestep 47 is:  nan
# The mean absolute error for the timestep 48 is:  nan
# The mean absolute error for the timestep 49 is:  nan
# The mean absolute error for the timestep 50 is:  nan
# The mean absolute error for the timestep 51 is:  nan
# The mean absolute error for the timestep 52 is:  nan
# The mean absolute error for the timestep 53 is:  nan
# The mean absolute error for the timestep 54 is:  nan
# The mean absolute error for the timestep 55 is:  nan
# The mean absolute error for the timestep 56 is:  nan
# The mean absolute error for the timestep 57 is:  nan
# The mean absolute error for the timestep 58 is:  nan
# The mean absolute error for the timestep 59 is:  nan
# The mean absolute error for the timestep 60 is:  nan
# The mean absolute error for the timestep 61 is:  nan
# The mean absolute error for the timestep 62 is:  nan
# The mean absolute error for the timestep 63 is:  nan
# The mean absolute error for the timestep 64 is:  nan
# The mean absolute error for the timestep 65 is:  nan
# The mean absolute error for the timestep 66 is:  nan
# The mean absolute error for the timestep 67 is:  nan
# The mean absolute error for the timestep 68 is:  nan
# The mean absolute error for the timestep 69 is:  nan
# The mean absolute error for the timestep 70 is:  nan
# The mean absolute error for the timestep 71 is:  nan
# The mean absolute error for the timestep 72 is:  nan
# The mean absolute error for the timestep 73 is:  nan
# The mean absolute error for the timestep 74 is:  nan
# The mean absolute error for the timestep 75 is:  nan
# The mean absolute error for the timestep 76 is:  nan
# The mean absolute error for the timestep 77 is:  nan
# The mean absolute error for the timestep 78 is:  nan
# The mean absolute error for the timestep 79 is:  nan
# The mean absolute error for the timestep 80 is:  nan
# The mean absolute error for the timestep 81 is:  nan
# The mean absolute error for the timestep 82 is:  nan
# The mean absolute error for the timestep 83 is:  nan
# The mean absolute error for the timestep 84 is:  nan
# The mean absolute error for the timestep 85 is:  nan
# The mean absolute error for the timestep 86 is:  nan
# The mean absolute error for the timestep 87 is:  nan
# The mean absolute error for the timestep 88 is:  nan
# The mean absolute error for the timestep 89 is:  nan
# The mean absolute error for the timestep 90 is:  nan
# The mean absolute error for the timestep 91 is:  nan
# The mean absolute error for the timestep 92 is:  nan
# The mean absolute error for the timestep 93 is:  nan
# The mean absolute error for the timestep 94 is:  nan
# The mean absolute error for the timestep 95 is:  nan
# The mean absolute error for the timestep 96 is:  nan
# The mean absolute error for the timestep 97 is:  nan
# The mean absolute error for the timestep 98 is:  nan
# The mean absolute error for the timestep 99 is:  nan
# The mean absolute error for the timestep 100 is:  nan
# The mean absolute error for the timestep 101 is:  nan
# The mean absolute error for the timestep 102 is:  nan
# The mean absolute error for the timestep 103 is:  nan
# The mean absolute error for the timestep 104 is:  nan
# The mean absolute error for the timestep 105 is:  nan
# The mean absolute error for the timestep 106 is:  nan
# The mean absolute error for the timestep 107 is:  nan
# The mean absolute error for the timestep 108 is:  nan
# The mean absolute error for the timestep 109 is:  nan
# The mean absolute error for the timestep 110 is:  nan
# The mean absolute error for the timestep 111 is:  nan
# The mean absolute error for the timestep 112 is:  nan
# The mean absolute error for the timestep 113 is:  nan
# The mean absolute error for the timestep 114 is:  nan
# The mean absolute error for the timestep 115 is:  nan
# The mean absolute error for the timestep 116 is:  nan
# The mean absolute error for the timestep 117 is:  nan
# The mean absolute error for the timestep 118 is:  nan
# The mean absolute error for the timestep 119 is:  nan
# The mean absolute error for the timestep 120 is:  nan
# The mean absolute error for the timestep 121 is:  nan
# The mean absolute error for the timestep 122 is:  nan
# The mean absolute error for the timestep 123 is:  nan
# The mean absolute error for the timestep 124 is:  nan
# The mean absolute error for the timestep 125 is:  nan
# The mean absolute error for the timestep 126 is:  nan
# The mean absolute error for the timestep 127 is:  nan
# The mean absolute error for the timestep 128 is:  nan
# The mean absolute error for the timestep 129 is:  nan
# The mean absolute error for the timestep 130 is:  nan
# The mean absolute error for the timestep 131 is:  nan
# The mean absolute error for the timestep 132 is:  nan
# The mean absolute error for the timestep 133 is:  nan
# The mean absolute error for the timestep 134 is:  nan
# The mean absolute error for the timestep 135 is:  nan
# The mean absolute error for the timestep 136 is:  nan
# The mean absolute error for the timestep 137 is:  nan
# The mean absolute error for the timestep 138 is:  nan
# The mean absolute error for the timestep 139 is:  nan
# The mean absolute error for the timestep 140 is:  nan
# The mean absolute error for the timestep 141 is:  nan
# The mean absolute error for the timestep 142 is:  nan
# The mean absolute error for the timestep 143 is:  nan
# The mean absolute error for the timestep 144 is:  nan
# The mean absolute error for the timestep 145 is:  nan
# The mean absolute error for the timestep 146 is:  nan
# The mean absolute error for the timestep 147 is:  nan
# The mean absolute error for the timestep 148 is:  nan
# The mean absolute error for the timestep 149 is:  nan
# The mean absolute error for the timestep 150 is:  nan
# The mean absolute error for the timestep 151 is:  nan
# The mean absolute error for the timestep 152 is:  nan
# The mean absolute error for the timestep 153 is:  nan
# The mean absolute error for the timestep 154 is:  nan
# The mean absolute error for the timestep 155 is:  nan
# The mean absolute error for the timestep 156 is:  nan
# The mean absolute error for the timestep 157 is:  nan
# The mean absolute error for the timestep 158 is:  nan
# The mean absolute error for the timestep 159 is:  nan
# The mean absolute error for the timestep 160 is:  nan
# The mean absolute error for the timestep 161 is:  nan
# The mean absolute error for the timestep 162 is:  nan
# The mean absolute error for the timestep 163 is:  nan
# The mean absolute error for the timestep 164 is:  nan
# The mean absolute error for the timestep 165 is:  nan
# The mean absolute error for the timestep 166 is:  nan
# The mean absolute error for the timestep 167 is:  nan
# The mean absolute error for the timestep 168 is:  nan
# The mean absolute error for the timestep 169 is:  nan
# The mean absolute error for the timestep 170 is:  nan
# The mean absolute error for the timestep 171 is:  nan
# The mean absolute error for the timestep 172 is:  nan
# The mean absolute error for the timestep 173 is:  nan
# The mean absolute error for the timestep 174 is:  nan
# The mean absolute error for the timestep 175 is:  nan
# The mean absolute error for the timestep 176 is:  nan
# The mean absolute error for the timestep 177 is:  nan
# The mean absolute error for the timestep 178 is:  nan
# The mean absolute error for the timestep 179 is:  nan
# The mean absolute error for the timestep 180 is:  nan
# The mean absolute error for the timestep 181 is:  nan
# The mean absolute error for the timestep 182 is:  nan
# The mean absolute error for the timestep 183 is:  nan
# The mean absolute error for the timestep 184 is:  nan
# The mean absolute error for the timestep 185 is:  nan
# The mean absolute error for the timestep 186 is:  nan
# The mean absolute error for the timestep 187 is:  nan
# The mean absolute error for the timestep 188 is:  nan
# The mean absolute error for the timestep 189 is:  nan
# The mean absolute error for the timestep 190 is:  nan
# The mean absolute error for the timestep 191 is:  nan
# The mean absolute error for the timestep 192 is:  nan

# %%
#https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/

# %% [markdown]
# # CLASSIFICATION

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf = KNeighborsClassifier(24)
clf.fit(X_train, y_train_one_class)
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test_one_class, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 69.17%

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
model = XGBClassifier(max_depth = 3, n_estimators = 50)
model.fit(X_train, y_train_one_class)
#model.fit(X_train, y)
y_pred = model.predict(X_test)
#acc = accuracy_score(y_test_one_class, y_pred)
acc = accuracy_score(y_test_one_class, y_pred)
print("Accuracy: %.2f%%" % (acc * 100.0))
# Out:
# Accuracy: 75.05%
# /Users/leobix/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
plt.hist(y_pred - y_test, bins = 12)
plt.show()

# %%
y_pred = model.predict(X_test[:,24:,0])
# Out:
# /Users/leobix/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
mse = mean_squared_error(y_test[:,24,0], y_pred)
mae = mean_absolute_error(y_test[:,24,0], y_pred)
print("MSE: %.2f%%" % (mse))
print("MAE %.2f%%" % (mae))
#7 depth, 100 estimators, 4.299 on test set
#5 depth, 100, MSE 4.16, MAE = 1.56
# Out:
# MSE: 4.16%
# MAE 1.56%

# %%
mse = mean_squared_error(y_test[:,24,0], X_test[:,47,0])
mae = mean_absolute_error(y_test[:,24,0], X_test[:,47,0])
print("Baseline MSE: %.2f%%" % (mse))
print("Baseline MAE %.2f%%" % (mae))
# Out:
# Baseline MSE: 4.56%
# Baseline MAE 1.63%

# %%
plt.plot(y_test[:,24,0], y_pred, 'bo')
plt.show()

# %%
print(model.feature_importances_)
# Out:
# [0.04198295 0.03818395 0.0404564  0.04003146 0.04139919 0.03841325
#  0.03943534 0.0384791  0.03923595 0.03917813 0.03830309 0.03902938
#  0.03928078 0.03948116 0.04018822 0.03994483 0.04006547 0.03910648
#  0.03890779 0.04077559 0.03983012 0.03931347 0.04777089 0.08120697]

# %% [markdown]
# # TBATS

# %%
from tbats import TBATS

# %%
n = 1000
gap = 960 
y = data.speed[n:n+gap]

# Create estimator
estimator = TBATS(seasonal_periods=[96])

# Fit model
fitted_model = estimator.fit(y)

# %%
# Forecast 192 steps ahead
y_forecasted = fitted_model.forecast(steps=192)

# Summarize fitted model
print(fitted_model.summary())
# Out:
# Use Box-Cox: False
# Use trend: True
# Use damped trend: True
# Seasonal periods: []
# Seasonal harmonics []
# ARMA errors (p, q): (0, 0)
# Smoothing (Alpha): 0.877266
# Trend (Beta): -0.107983
# Damping Parameter (Phi): 0.882009
# Seasonal Parameters (Gamma): []
# AR coefficients []
# MA coefficients []
# Seed vector [4.54855843 0.05034197]
#
# AIC 6129.662197

# %%
plt.plot([i for i in range(192)], y_forecasted)
plt.plot([i for i in range(192)], data.speed[n+gap:n+gap+192])
plt.show()

# %%
mae = mean_absolute_error(data.speed[n+gap:n+gap+192], y_forecasted)
mae
# Out:
# 1.473546719371943

# %% [markdown]
# # VAR technique for multivariate forecasting

# %%
from statsmodels.tsa.vector_ar.var_model import VAR

# %%
model = VAR(endog=dataset)
model_fit = model.fit()

# %%
dataset_test.shape
# Out:
# (30000, 3)

# %%
prediction = model_fit.forecast(dataset_test[:40], steps=192)

# %%
prediction.shape
# Out:
# (192, 3)

# %%
plt.plot([i for i in range(192)],prediction[:,0])
plt.plot([i for i in range(192)], y_test[0,:,0])
plt.show()

# %%
from tsfresh import select_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_features

extracted_features = extract_features(avg_data[100:1000], column_id = avg_data.index)
#impute(extracted_features)
#features_filtered = select_features(extracted_features, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-3a8f3fc56a67> in <module>()
#       3 from tsfresh import extract_features
#       4
# ----> 5 extracted_features = extract_features(avg_data[100:1000], column_id = avg_data.index)
#       6 #impute(extracted_features)
#       7 #features_filtered = select_features(extracted_features, y)
#
# ~/anaconda3/lib/python3.6/site-packages/tsfresh/feature_extraction/extraction.py in extract_features(timeseries_container, default_fc_parameters, kind_to_fc_parameters, column_id, column_sort, column_kind, column_value, chunksize, n_jobs, show_warnings, disable_progressbar, impute_function, profile, profiling_filename, profiling_sorting, distributor)
#     142             column_id=column_id, column_kind=column_kind,
#     143             column_sort=column_sort,
# --> 144             column_value=column_value)
#     145     # Use the standard setting if the user did not supply ones himself.
#     146     if default_fc_parameters is None and kind_to_fc_parameters is None:
#
# ~/anaconda3/lib/python3.6/site-packages/tsfresh/utilities/dataframe_functions.py in _normalize_input_to_internal_representation(timeseries_container, column_id, column_sort, column_kind, column_value)
#     292         raise ValueError("You have to set the column_id which contains the ids of the different time series")
#     293
# --> 294     if column_id not in timeseries_container.columns:
#     295         raise AttributeError("The given column for the id is not present in the data.")
#     296
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    4228     @Appender(_index_shared_docs["contains"] % _index_doc_kwargs)
#    4229     def __contains__(self, key):
# -> 4230         hash(key)
#    4231         try:
#    4232             return key in self._engine
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __hash__(self)
#    4255
#    4256     def __hash__(self):
# -> 4257         raise TypeError("unhashable type: %r" % type(self).__name__)
#    4258
#    4259     def __setitem__(self, key, value):
#
# TypeError: unhashable type: 'DatetimeIndex'
